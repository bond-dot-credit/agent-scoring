# %% [markdown]
# # ERC-4626: Scanning all vaults onchain

# %%
import os

os.environ["JSON_RPC_URL"] = "https://mainnet.infura.io/v3/6ec2c1604e2d477f9c9f7ea52aa8e0f3"

# %%
import sys
print(sys.executable)
# Out:
# /Users/olaoluwatunmise/stablecoin_vaults/vaults/bin/python

# %%
import sys
# !{sys.executable} -m pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /Users/olaoluwatunmise/stablecoin_vaults/vaults/lib/python3.10/site-packages (20.0.0)

# %%
import sys
# !{sys.executable} -m pip install fastparquet
# Out:
# Requirement already satisfied: fastparquet in /Users/olaoluwatunmise/stablecoin_vaults/vaults/lib/python3.10/site-packages (2024.11.0)
# Requirement already satisfied: pandas>=1.5.0 in /Users/olaoluwatunmise/stablecoin_vaults/vaults/lib/python3.10/site-packages (from fastparquet) (2.3.1)
# Requirement already satisfied: numpy in /Users/olaoluwatunmise/stablecoin_vaults/vaults/lib/python3.10/site-packages (from fastparquet) (2.2.6)
# Requirement already satisfied: cramjam>=2.3 in /Users/olaoluwatunmise/stablecoin_vaults/vaults/lib/python3.10/site-packages (from fastparquet) (2.10.0)
# Requirement already satisfied: fsspec in /Users/olaoluwatunmise/stablecoin_vaults/vaults/lib/python3.10/site-packages (from fastparquet) (2025.5.1)
# Requirement already satisfied: packaging in /Users/olaoluwatunmise/stablecoin_vaults/vaults/lib/python3.10/site-packages (from fastparquet) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/olaoluwatunmise/stablecoin_vaults/vaults/lib/python3.10/site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/olaoluwatunmise/stablecoin_vaults/vaults/lib/python3.10/site-packages (from pandas>=1.5.0->fastparquet) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/olaoluwatunmise/stablecoin_vaults/vaults/lib/python3.10/site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/olaoluwatunmise/stablecoin_vaults/vaults/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# !{sys.executable} -m pip install coloredlogs

# !pip install nest_asyncio

# %%
# Setup and Configuration

"""Scan all ERC-4626 vaults on Base.

- Set up a HyperSync based vault discovery client
- As the writing of this, we get 1108 leads on Base
- Takes environment variables ``JSON_RPC_URL``, ``LOG_LEVEL``, ``END_BLOCK``
- Save data to /tmp: both raw Python objects and Parquet dump

Usage:

.. code-block:: shell

    export JSON_RPC_URL=...
    python scripts/erc-4626/scan-vaults.py

Or for faster small sample scan limit the end block:

    END_BLOCK=5555721 python scripts/erc-4626/scan-vaults.py

"""

import decimal
import logging
import os
import pickle
import sys
from decimal import Decimal
from pathlib import Path
from urllib.parse import urlparse

import pandas as pd
from IPython.core.display_functions import display
from joblib import Parallel, delayed

from tqdm_loggable.auto import tqdm

from eth_defi.chain import get_chain_name
from eth_defi.erc_4626.core import ERC4626Feature
from eth_defi.erc_4626.hypersync_discovery import HypersyncVaultDiscover
from eth_defi.erc_4626.scan import create_vault_scan_record_subprocess
from eth_defi.hypersync.server import get_hypersync_server
from eth_defi.provider.named import get_provider_name
from eth_defi.utils import setup_console_logging

try:
    import hypersync
except ImportError as e:
    raise ImportError("Install the library with optional HyperSync dependency to use this module") from e

from eth_defi.provider.multi_provider import create_multi_provider_web3, MultiProviderWeb3Factory


logger = logging.getLogger(__name__)


# Read JSON_RPC_CONFIGURATION from the environment
JSON_RPC_URL = os.environ.get("JSON_RPC_URL")
if JSON_RPC_URL is None:
    try:
        urlparse(JSON_RPC_URL)
    except ValueError as e:
        raise ValueError(f"Invalid JSON_RPC URL: {JSON_RPC_URL}") from e

# %%
def main():
    setup_console_logging()

    # How many CPUs / subprocess we use
    #max_workers = 16
    max_workers = 1  # To debug, set workers to 1

    web3 = create_multi_provider_web3(JSON_RPC_URL)
    web3factory = MultiProviderWeb3Factory(JSON_RPC_URL, retries=5)
    name = get_chain_name(web3.eth.chain_id)
    rpcs = get_provider_name(web3.provider)
    print(f"Scanning ERC-4626 vaults on chain {web3.eth.chain_id}: {name}, using rpcs: {rpcs}")

    hypersync_url = get_hypersync_server(web3)
    client = hypersync.HypersyncClient(hypersync.ClientConfig(url=hypersync_url))

    start_block = 1

    end_block = os.environ.get("END_BLOCK")
    if end_block is None:
        end_block = web3.eth.block_number
    else:
        end_block = int(end_block)

    # output_folder = os.environ.get("OUTPUT_FOLDER")
    # if output_folder is None:
    #     output_folder = Path("~/.tradingstrategy/vaults").expanduser()
    # else:
    #     output_folder = Path(output_folder).expanduser()

    # os.makedirs(output_folder, exist_ok=True)

    output_folder = os.environ.get("OUTPUT_FOLDER")
    if output_folder is None:
        output_folder = Path("/Users/olaoluwatunmise/stablecoin_vaults/database")
    else:
        output_folder = Path(output_folder).expanduser()

    os.makedirs(output_folder, exist_ok=True)

    # Create a scanner that uses web3, HyperSync and subprocesses
    vault_discover = HypersyncVaultDiscover(
        web3,
        web3factory,
        client,
        max_workers=max_workers,
    )

    # Perform vault discovery and categorisation,
    # so we get information which address contains which kind of a vault
    vault_detections = list(vault_discover.scan_vaults(start_block, end_block))
    # Process only first 100 vaults for testing
    vault_detections = vault_detections[:100]  

    # Prepare data export by reading further per-vault data using multiprocessing
    worker_processor = Parallel(n_jobs=max_workers)
    logger.info("Extracting remaining vault metadata for %d vaults", len(vault_detections))

    # Quite a mouthful line to create a row of output for each vault detection using subproces pool
    desc = f"Extracting vault metadata using {max_workers} workers"
    rows = worker_processor(delayed(create_vault_scan_record_subprocess)(web3factory, d, end_block) for d in tqdm(vault_detections, desc=desc))

    print(f"Total {len(rows)} vaults detected")

    chain = web3.eth.chain_id

    if len(rows) == 0:
        print(f"No vaults found on chain {chain}, not generating any database updates")
        sys.exit(0)

    df = pd.DataFrame(rows)
    # Parquet cannot export the raw Python objects,
    # so we remove columns that are marked Python-internal only
    df = df.drop(columns=[col for col in df.columns if col.startswith("_")])
    df = df.sort_values("First seen")

    #
    # Save raw data rows
    #

    output_fname = Path(f"{output_folder}/chain-{chain}-vaults.parquet")
    parquet_df = df.copy()
    parquet_df = parquet_df.fillna(pd.NA)  # fillna replaces None and NaN with pd.NA
    # Avoid funny number issues
    # pyarrow.lib.ArrowInvalid: ('Decimal precision out of range [1, 76]: 90', 'Conversion failed for column NAV with type object')
    parquet_df["Mgmt fee"] = pd.to_numeric(parquet_df["Mgmt fee"], errors="coerce").astype("float64")
    parquet_df["Perf fee"] = pd.to_numeric(parquet_df["Perf fee"], errors="coerce").astype("float64")
    parquet_df["Shares"] = pd.to_numeric(parquet_df["Shares"], errors="coerce").astype("float64")
    parquet_df["NAV"] = pd.to_numeric(parquet_df["NAV"], errors="coerce").astype("float64")
    print(f"Saving raw data to {output_fname}")
    parquet_df.to_parquet(output_fname)

    #
    # Save machine-readable output
    #

    # Save dict -> data mapping with raw data to be read in notebooks and such.
    # This will preserve raw vault detection objects.
    # Keyed by (chain id, address)
    data_dict = {r["_detection_data"].get_spec(): r for r in rows}
    output_fname = Path(f"{output_folder}/vault-db.pickle")
    print(f"Saving vault pickled database to {output_fname}")
    if not output_fname.exists():
        existing_db = {}
    else:
        existing_db = pickle.load(output_fname.open("rb"))
        assert type(existing_db) == dict, f"Got: {type(existing_db)}: {existing_db}"
    # Merge new results
    existing_db.update(data_dict)
    pickle.dump(existing_db, output_fname.open("wb"))
    print(f"Vault database has {len(existing_db)} entries")

    #
    # Display in terminal
    #

    # Format DataFrame output for terminal
    df["First seen"] = df["First seen"].dt.strftime("%Y-%b-%d")
    df["Mgmt fee"] = df["Mgmt fee"].apply(lambda x: f"{x:.1%}" if type(x) == float else "-")
    df["Perf fee"] = df["Perf fee"].apply(lambda x: f"{x:.1%}" if type(x) == float else "-")
    # df["Address"] = df["Address"].apply(lambda x: x[0:8])  # Address is too wide in terminal
    df = df.set_index("Address")

    # Round dust to zero, drop to 4 decimals
    def round_below_epsilon(x, epsilon=Decimal("0.1"), round_factor=Decimal("0.001")):
        if isinstance(x, Decimal):
            # Eliminate dust
            x = Decimal("0") if abs(x) < epsilon else x

            float_x = float(x)

            # Get rid of numbers with too many digits
            if float_x >= 1e12:  # Trillions
                return f"{float_x / 1e12:.1f}T"
            elif float_x >= 1e9:  # Billions
                return f"{float_x / 1e9:.1f}G"
            elif float_x >= 1e6:  # Millions
                return f"{float_x / 1e6:.1f}M"
            elif float_x >= 1e3:  # Millions
                return f"{float_x / 1e6:.1f}K"
            else:
                try:
                    x = x.quantize(round_factor)
                except decimal.InvalidOperation:
                    logger.warning("Cannot quantise: %s", x)

        return x  # Not decimal

    # Apply the function to all elements in the DataFrame
    df = df.apply(lambda col: col.map(round_below_epsilon))

    erc_7540s = [v for v in rows if ERC4626Feature.erc_7540_like in v["_detection_data"].features]
    print(f"Total: {len(df)} vaults detected")
    print(f"ERC-7540: {len(erc_7540s)} vaults detected")

    with pd.option_context("display.max_rows", None):
        display(df)


if __name__ == "__main__":
    main()
# Out:
# Scanning ERC-4626 vaults on chain 1: Ethereum, using rpcs: fallbacks mainnet.infura.io
# Scanning potential vault leads on chain 1:   0%|          | 0/22930869 [00:00<?, ?it/s]
# Identifying vaults, using 1 workers:   0%|          | 0/1303 [00:00<?, ?it/s]
# /Users/olaoluwatunmise/stablecoin_vaults/vaults/lib/python3.10/site-packages/joblib/parallel.py:1383: UserWarning: The backend class 'SequentialBackend' does not support timeout. You have set 'timeout=1800' in Parallel but the 'timeout' parameter will not be used.
#   warnings.warn(
# Extracting vault metadata using 1 workers:   0%|          | 0/100 [00:00<?, ?it/s]
# Total 100 vaults detected
# Saving raw data to /Users/olaoluwatunmise/stablecoin_vaults/database/chain-1-vaults.parquet
# Saving vault pickled database to /Users/olaoluwatunmise/stablecoin_vaults/database/vault-db.pickle
# Vault database has 100 entries
# Total: 100 vaults detected
# ERC-7540: 0 vaults detected
#                                                                          Symbol  \
# Address
# 0x20ccfcf19c622b4aeb5e476144382b9cff3c63f8
# 0x1e2a7796af48ca59ab1e1aecd30a532cace98eee
# 0xe63c3770823da6f9d9e2fd46bb2e0d0b78f87815
# 0xababb61a9f837aad53ed4320221737fc6e9dc84b
# 0x21db1a295875bdeaf6ce8ed1b1efc04f3c291b89                             (re)TOKE
# 0x4f93df7bc0421c9401fd3099cce4afe7678b0c63                              tsTRIBE
# 0xac4c093c777581dc9c4dc935394ff11e6c58cd45                              wfFEI-8
# 0x5dcaaf1f0b32244131fed00de9c4598ae526dab2                                  TTV
# 0x48f8d7943899d9b4f34ccb5ba1b92695433226e8                            cvxFXSFXS
# 0x497315203656958b8d82c905ed364ff7d67f0b44                           rETHwstETH
# 0xa066620554af0d50703e5ee3c58c022c6ae5339d                            cvxFXSFXS
# 0xb78ebb2248bb72380e690246f9631cf58c07b444                            cvxCRVCRV
# 0xd2af830e8cbdfed6cc11bab697bb25496ed6fa62                                WOUSD
# 0x4db37c056de510db0ba461ecb02fd0b2925f1473                              tsTRIBE
# 0xdf462a9d35e3785b0fb15549a047512b4fc71606                                tsBAL
# 0xd919d318c957cd4684998a54dc2c8ab9db9e76bf                               tsgOHM
# 0xf486608dbc7dd0eb80e4b9fa0fdb03e40f414030                          4626-fFEI-8
# 0x815c23eca83261b6ec689b60cc4a58b54bc24d8d                                vTHOR
# 0x30647a72dc82d7fbb1123ea74716ab8a317eac19                                imUSD
# 0x17d8cbb6bce8cee970a4027d1198f6700a7a6c24                                imBTC
# 0x4937a209d4cdbd3ecd48857277cfd4da4d82914c                                 xMPL
# 0x71e639aa132445d1aa2b2efc28f11964a4489277                          BAUSDC-2206
# 0x8659fc767cad6005de79af65dafe4249c57927af                                 uCVX
# 0x12d92fe0aa1c59c4f7a704d16561cfbaf17ec257                        ∞-yvWETH-xPYT
# 0xf9f875bd4b1bc19693fe3fe3c719f9deb11a2637                          aave2-CLR-S
# 0x44dd83e0598e7a3709cf0b2e59d3319418068a65                                veNWO
# 0x86e8062c9f9e5f852bb0d8fc3f33fc110e9b2e47                             stNEWOlp
# 0xdcee1c640cc270121faf145f231fd8ff1d8d5cd4             auraB-stETH-STABLE-vault
# 0x08b8a86b9498ac249bf4b86e14c5d4187085a239                    aurastaBAL3-vault
# 0xae327c28d13a497357ad2189b75c83e6ba8cadc6              aura20WETH-80WNCG-vault
# 0xcea3aa5b2a50e39c7c7755ebff1e9e1e1516d3f5            aura20WBTC-80BADGER-vault
# 0x4bf99dab15ca5da9ff6a0489509a8f196f9dff9f                            edn-stETH
# 0x79dfc65f77c67d95652294f301bee5dea3d951fb                         ∞-stETH-xPYT
# 0xf9a98a9452485ed55cd3ce5260c2b71c9807b11a                              wlstETH
# 0xbab1e97e9db257fb2ce11fb7044eacc838db8f11                              pystETH
# 0xbab1e772d70300422312dff12daddcb60864bd41                              stETHvv
# 0xdffc232ed74a25031a3e16c81013da22ac75806f               aura50DFX-50WETH-vault
# 0x7bad5df5e11151dc5ee1a648800057c5c934c0d5                          aave2-CLR-S
# 0xd15135141f1217b8863cb1431ad71309ef22ceda                          aave2-CLR-S
# 0xb4047ab92ed82c3f29c14010a955da6708a41244                   auraUSDC-PAL-vault
# 0x3808708e761b988d23ae011ed0e12674fb66bd62                                svXAI
# 0x3aea50829e33e976acb05454d356b27d94da9c83                               pvWBTC
# 0xdb836a975af2f41f82b863f6c22e127fa6fb968a                               pvWBTC
# 0x1ec71ddf391af2024b06f1c6dbb9a9896ced3015                                  pvE
# 0x10ca519614b0f3463890387c24819001affc5152  aura40WBTC-40DIGG-20graviAURA-vault
# 0x6d800bc192666936d612156f594357dafa8fc290                aura50COW-50GNO-vault
# 0x00000008786611c72a00909bd8d398b1be195be3                             refiUSDC
# 0xb9b2ecaa664fdcc6f7104e0cff5f3a690f0b3a4c               aura20WETH-80FDT-vault
# 0x63bbb71b68c76b78243d0a4aa463d34536788a15
# 0xdaf03d70fe637b91ba6e521a32e1fb39256d3ec9                                 aFXS
# 0x211bf3fe6f5fc8323e7f684459ceea08507ced94                               xSNACK
# 0x48db0de4fed4b978c1aea882bc8d9bf94b15a3b7                        ∞-yvUSDC-xPYT
# 0x6ebdc53b2c07378662940a7593ad39fb67778457              auraB-rETH-STABLE-vault
# 0x794f6b13fbd7eb7ef10d1ed205c9a416910207ff
# 0x32467a5fc2d72d21e8dce990906547a2b012f382
# 0xf4ee75d0d09f14248e942cb94ec909df7c600a85                aura20DAI-80TCR-vault
# 0x8784d80f3308ee0a0f0d40c5623b1454533b84e0             aura80TEMPLE-20DAI-vault
# 0x5ce40e68c1a011c1782499bf5ff01c910c792ba6                             FRP_USDC
# 0x60897720aa966452e8706e74296b018990aec527
# 0x84e1a90a8c1a677db704eb75b2ae79efa325f271
# 0x3c66b18f67ca6c1a71f829e2f6a0c987f97462d0
# 0xf40f9763c56b5b7b264d795fc77a859cdc43d79b                              xVIRTUE
# 0x7ff48b2cbbb4b4d414668bfdbe405cc29e2d1fb3                              xVIRTUE
# 0x20706baa0f89e2dccf48ea549ea5a13b9b30462f
# 0x4169df1b7820702f566cc10938da51f6f597d264
# 0x6bad6a9bcfda3fd60da6834ace5f93b8cfed9598
# 0x93283e9dce1394994a1fd4cdf02ff45ff5cdaac1                                 WETH
# 0x21c8898f1b30fef7af0c0146d2ba7ca34e3244be                                 WETH
# 0xa384c9cca28cc7a58093e4e9a0acacf8c20072fd                         yvSUSHI-4646
# 0x4e7300f74f59afaeccdc0d434758df9be238f0bf                              sfrxETH
# 0x347c77098a6ffcf1c7af2de9e96a1be854d70602                              uUSDCv3
# 0xa953f0c594365b821a847e7b9f4722e338526699                    multiposition-CLR
# 0xac3e018457b222d93114458476f3e3416abbe38f                              sfrxETH
# 0x33c42ec3a3f46b2afa5f567d713b9d6539f1991a                              uWETHv3
# 0xc4d57603d47fb842ec11a5332748f9f96d44cbeb
# 0xdbe88dbac39263c47629ebba02b3ef4cf0752a72
# 0xbfc413ea6cb68c05deda0d9aa7daf8e51a7dddff                                TestA
# 0xede95dbb60d2dca7cf90c42d6f416a2c7dfb4d5e                              wyvUSDC
# 0x6b7f87279982d919bbf85182ddeab179b366d8f2                          ETHBTCTrend
# 0x7983beb51580fa1e17f52d4e1686c11cbb473bbd                              uWBTCv3
# 0xb4b1500d09c4c07ab65474f7b980f426a5752a0e              yoSifu_Stargate_S*SGETH
# 0x6e2dac3b9e9adc0cbbae2d0b9fd81952a8d33872                            ETHBTCMom
# 0xb9b47e72819934d7a5d60bf08cd2c78072383ebb                         vcx3CRV-mUSD
# 0x98c5910823c2e67d54e4e0c03de44043dbfa7ca8                         vcx3CRV-FRAX
# 0x87ed92648fae3b3930577c92c8a247b127ed8949                         vcx3CRV-BUSD
# 0x9614a4c61e45575b56c7e0251f63dcde797d93c5                           mv3CRV-CVX
# 0x455fb969dc06c4aa77e7db3f0686cc05164436d2                          mvUSDC-3PCV
# 0x50e627a1df8d665524942ad7ec6392b6ba60293a
# 0x4607da637e5d182419de0118b4c49562bdf09dac                     yoS_Strgt_S*USDC
# 0x52ecdbcdca159e020597f6eb7fb90a3e715ea3c1               yoSifu_Stargate_S*USDC
# 0x87d7fff9c1d2dba7dee527efe7e89257d4fb9209                                 WETH
# 0x3843c41da1d7909c86fad51c47b9a97cf62a29e1                            exawstETH
# 0xd6b11df2a86a9ffd3437e6af2ed7889092f66a67                       ERC4626crvFRAX
# 0x55dff0b17dcde1a36b1b2987e597a7700fb2241e                      ERC4626usdn3CRV
# 0x46a24d4b38f4e760005d74bf03b99b1ff096558c                ERC4626USDD3CRV3CRV-f
# 0x87f74d68e5c561eb1f9b7e6d3f99483a752d7d6b                 ERC4626MIM-3LP3CRV-f
# 0x53273ea2feb6c60163b0815da27a184d6055bfde                        ERC4626yvUSDT
# 0x39fc9b8df2a36dc70c79ddafafabb4d2e1598f09                              USDTVLT
# 0x45a6c7d5af31948b79e0eafe7c299e7e20b9ece1                    ERC4626LUSD3CRV-f
# 0xde3ae5abf47f0a7be34b85a61ecd121807ede4cc                        ERC4626yvUSDC
#
#                                                                                          Name  \
# Address
# 0x20ccfcf19c622b4aeb5e476144382b9cff3c63f8
# 0x1e2a7796af48ca59ab1e1aecd30a532cace98eee
# 0xe63c3770823da6f9d9e2fd46bb2e0d0b78f87815
# 0xababb61a9f837aad53ed4320221737fc6e9dc84b
# 0x21db1a295875bdeaf6ce8ed1b1efc04f3c291b89                          (Re)cycler Staked Tokemak
# 0x4f93df7bc0421c9401fd3099cce4afe7678b0c63                                   Tribe Turbo Safe
# 0xac4c093c777581dc9c4dc935394ff11e6c58cd45                                   FeiRari FEI 4626
# 0x5dcaaf1f0b32244131fed00de9c4598ae526dab2                                 tTCR-Tokemak-Vault
# 0x48f8d7943899d9b4f34ccb5ba1b92695433226e8                            cvxFXSFXS Convex Plugin
# 0x497315203656958b8d82c905ed364ff7d67f0b44                          rETH-wstETH Convex Plugin
# 0xa066620554af0d50703e5ee3c58c022c6ae5339d                            cvxFXSFXS Convex Plugin
# 0xb78ebb2248bb72380e690246f9631cf58c07b444                            cvxCRVCRV Convex Plugin
# 0xd2af830e8cbdfed6cc11bab697bb25496ed6fa62                                       Wrapped OUSD
# 0x4db37c056de510db0ba461ecb02fd0b2925f1473                                   Tribe Turbo Safe
# 0xdf462a9d35e3785b0fb15549a047512b4fc71606                                Balancer Turbo Safe
# 0xd919d318c957cd4684998a54dc2c8ab9db9e76bf                          Governance OHM Turbo Safe
# 0xf486608dbc7dd0eb80e4b9fa0fdb03e40f414030                      Fuse Pool 8 FEI ERC4626 Vault
# 0x815c23eca83261b6ec689b60cc4a58b54bc24d8d                                              vTHOR
# 0x30647a72dc82d7fbb1123ea74716ab8a317eac19                              Interest bearing mUSD
# 0x17d8cbb6bce8cee970a4027d1198f6700a7a6c24                       Interest bearing mStable BTC
# 0x4937a209d4cdbd3ecd48857277cfd4da4d82914c                                               xMPL
# 0x71e639aa132445d1aa2b2efc28f11964a4489277                                Basic Arb USDC 2206
# 0x8659fc767cad6005de79af65dafe4249c57927af                                        Union Pirex
# 0x12d92fe0aa1c59c4f7a704d16561cfbaf17ec257                           Timeless Yearn WETH xPYT
# 0xf9f875bd4b1bc19693fe3fe3c719f9deb11a2637       Sommelier Aave V2 Stablecoin Cellar LP Token
# 0x44dd83e0598e7a3709cf0b2e59d3319418068a65                                             veNewO
# 0x86e8062c9f9e5f852bb0d8fc3f33fc110e9b2e47                                     staked NEWO LP
# 0xdcee1c640cc270121faf145f231fd8ff1d8d5cd4      Balancer stETH Stable Pool Aura Deposit Vault
# 0x08b8a86b9498ac249bf4b86e14c5d4187085a239        Balancer USD Stable Pool Aura Deposit Vault
# 0xae327c28d13a497357ad2189b75c83e6ba8cadc6                   20WETH-80WNCG Aura Deposit Vault
# 0xcea3aa5b2a50e39c7c7755ebff1e9e1e1516d3f5                 20WBTC-80BADGER Aura Deposit Vault
# 0x4bf99dab15ca5da9ff6a0489509a8f196f9dff9f                     EDEN DAO LIDO STAKED ETH VAULT
# 0x79dfc65f77c67d95652294f301bee5dea3d951fb                           Timeless Lido stETH xPYT
# 0xf9a98a9452485ed55cd3ce5260c2b71c9807b11a                         ERC4626-Wrapped Lido stETH
# 0xbab1e97e9db257fb2ce11fb7044eacc838db8f11                                   Pods Yield stETH
# 0xbab1e772d70300422312dff12daddcb60864bd41                             stETH Volatility Vault
# 0xdffc232ed74a25031a3e16c81013da22ac75806f                    50DFX-50WETH Aura Deposit Vault
# 0x7bad5df5e11151dc5ee1a648800057c5c934c0d5       Sommelier Aave V2 Stablecoin Cellar LP Token
# 0xd15135141f1217b8863cb1431ad71309ef22ceda       Sommelier Aave V2 Stablecoin Cellar LP Token
# 0xb4047ab92ed82c3f29c14010a955da6708a41244                        USDC-PAL Aura Deposit Vault
# 0x3808708e761b988d23ae011ed0e12674fb66bd62                    SideShift SideShift Token Vault
# 0x3aea50829e33e976acb05454d356b27d94da9c83                                             pvWBTC
# 0xdb836a975af2f41f82b863f6c22e127fa6fb968a                                             pvWBTC
# 0x1ec71ddf391af2024b06f1c6dbb9a9896ced3015                                                pvE
# 0x10ca519614b0f3463890387c24819001affc5152       40WBTC-40DIGG-20graviAURA Aura Deposit Vault
# 0x6d800bc192666936d612156f594357dafa8fc290                 50COW-50GNO BPT Aura Deposit Vault
# 0x00000008786611c72a00909bd8d398b1be195be3                                    REFI USDC Vault
# 0xb9b2ecaa664fdcc6f7104e0cff5f3a690f0b3a4c                    20WETH-80FDT Aura Deposit Vault
# 0x63bbb71b68c76b78243d0a4aa463d34536788a15
# 0xdaf03d70fe637b91ba6e521a32e1fb39256d3ec9                                 Aladdin cvxFXS/FXS
# 0x211bf3fe6f5fc8323e7f684459ceea08507ced94                      Auto Compounding Picniq Token
# 0x48db0de4fed4b978c1aea882bc8d9bf94b15a3b7                          Timeless USDC yVault xPYT
# 0x6ebdc53b2c07378662940a7593ad39fb67778457       Balancer rETH Stable Pool Aura Deposit Vault
# 0x794f6b13fbd7eb7ef10d1ed205c9a416910207ff
# 0x32467a5fc2d72d21e8dce990906547a2b012f382
# 0xf4ee75d0d09f14248e942cb94ec909df7c600a85                     20DAI-80TCR Aura Deposit Vault
# 0x8784d80f3308ee0a0f0d40c5623b1454533b84e0                  80TEMPLE-20DAI Aura Deposit Vault
# 0x5ce40e68c1a011c1782499bf5ff01c910c792ba6                                     FRP_USDC_VAULT
# 0x60897720aa966452e8706e74296b018990aec527
# 0x84e1a90a8c1a677db704eb75b2ae79efa325f271
# 0x3c66b18f67ca6c1a71f829e2f6a0c987f97462d0
# 0xf40f9763c56b5b7b264d795fc77a859cdc43d79b                                            xVirtue
# 0x7ff48b2cbbb4b4d414668bfdbe405cc29e2d1fb3                                            xVirtue
# 0x20706baa0f89e2dccf48ea549ea5a13b9b30462f
# 0x4169df1b7820702f566cc10938da51f6f597d264
# 0x6bad6a9bcfda3fd60da6834ace5f93b8cfed9598
# 0x93283e9dce1394994a1fd4cdf02ff45ff5cdaac1                                      Wrapped Ether
# 0x21c8898f1b30fef7af0c0146d2ba7ca34e3244be                                      Wrapped Ether
# 0xa384c9cca28cc7a58093e4e9a0acacf8c20072fd                          SUSHI yVault-4646-Adapter
# 0x4e7300f74f59afaeccdc0d434758df9be238f0bf                                  Staked Frax Ether
# 0x347c77098a6ffcf1c7af2de9e96a1be854d70602                           Unagii USD Coin Vault v3
# 0xa953f0c594365b821a847e7b9f4722e338526699                      Multiposition Cellar LP Token
# 0xac3e018457b222d93114458476f3e3416abbe38f                                  Staked Frax Ether
# 0x33c42ec3a3f46b2afa5f567d713b9d6539f1991a                      Unagii Wrapped Ether Vault v3
# 0xc4d57603d47fb842ec11a5332748f9f96d44cbeb
# 0xdbe88dbac39263c47629ebba02b3ef4cf0752a72
# 0xbfc413ea6cb68c05deda0d9aa7daf8e51a7dddff                                             Test-A
# 0xede95dbb60d2dca7cf90c42d6f416a2c7dfb4d5e                                     Wrapped yvUSDC
# 0x6b7f87279982d919bbf85182ddeab179b366d8f2                                      ETH-BTC Trend
# 0x7983beb51580fa1e17f52d4e1686c11cbb473bbd                        Unagii Wrapped BTC Vault v3
# 0xb4b1500d09c4c07ab65474f7b980f426a5752a0e  Yield Optimized Mary -Stargate Ether Vault-LP-...
# 0x6e2dac3b9e9adc0cbbae2d0b9fd81952a8d33872                                   ETH-BTC Momentum
# 0xb9b47e72819934d7a5d60bf08cd2c78072383ebb                             3Crv Convex mUSD Vault
# 0x98c5910823c2e67d54e4e0c03de44043dbfa7ca8                             3Crv Convex FRAX Vault
# 0x87ed92648fae3b3930577c92c8a247b127ed8949                             3Crv Convex BUSD Vault
# 0x9614a4c61e45575b56c7e0251f63dcde797d93c5                             3CRV Convex Meta Vault
# 0x455fb969dc06c4aa77e7db3f0686cc05164436d2                       USDC 3Pool Convex Meta Vault
# 0x50e627a1df8d665524942ad7ec6392b6ba60293a
# 0x4607da637e5d182419de0118b4c49562bdf09dac                  Y Opt S -USD Coin-LP- Strgt Vault
# 0x52ecdbcdca159e020597f6eb7fb90a3e715ea3c1  Yield Optimized Sifu -USD Coin-LP- Stargate Vault
# 0x87d7fff9c1d2dba7dee527efe7e89257d4fb9209                                      Wrapped Ether
# 0x3843c41da1d7909c86fad51c47b9a97cf62a29e1                                     exactly wstETH
# 0xd6b11df2a86a9ffd3437e6af2ed7889092f66a67                         Wrapped Curve.fi FRAX/USDC
# 0x55dff0b17dcde1a36b1b2987e597a7700fb2241e                         Wrapped Curve.fi USDN/3Crv
# 0x46a24d4b38f4e760005d74bf03b99b1ff096558c   Wrapped Curve.fi Factory USD Metapool: USDD/3CRV
# 0x87f74d68e5c561eb1f9b7e6d3f99483a752d7d6b  Wrapped Curve.fi Factory USD Metapool: Magic I...
# 0x53273ea2feb6c60163b0815da27a184d6055bfde                                Wrapped USDT yVault
# 0x39fc9b8df2a36dc70c79ddafafabb4d2e1598f09                                   Tether USD vault
# 0x45a6c7d5af31948b79e0eafe7c299e7e20b9ece1     Wrapped Curve.fi Factory USD Metapool: Liquity
# 0xde3ae5abf47f0a7be34b85a61ecd121807ede4cc                                Wrapped USDC yVault
#
#                                                       Protocol  \
# Address
# 0x20ccfcf19c622b4aeb5e476144382b9cff3c63f8           <unknown>
# 0x1e2a7796af48ca59ab1e1aecd30a532cace98eee           <unknown>
# 0xe63c3770823da6f9d9e2fd46bb2e0d0b78f87815           <unknown>
# 0xababb61a9f837aad53ed4320221737fc6e9dc84b           <unknown>
# 0x21db1a295875bdeaf6ce8ed1b1efc04f3c291b89  <unknown ERC-4626>
# 0x4f93df7bc0421c9401fd3099cce4afe7678b0c63  <unknown ERC-4626>
# 0xac4c093c777581dc9c4dc935394ff11e6c58cd45  <unknown ERC-4626>
# 0x5dcaaf1f0b32244131fed00de9c4598ae526dab2  <unknown ERC-4626>
# 0x48f8d7943899d9b4f34ccb5ba1b92695433226e8  <unknown ERC-4626>
# 0x497315203656958b8d82c905ed364ff7d67f0b44  <unknown ERC-4626>
# 0xa066620554af0d50703e5ee3c58c022c6ae5339d  <unknown ERC-4626>
# 0xb78ebb2248bb72380e690246f9631cf58c07b444  <unknown ERC-4626>
# 0xd2af830e8cbdfed6cc11bab697bb25496ed6fa62  <unknown ERC-4626>
# 0x4db37c056de510db0ba461ecb02fd0b2925f1473  <unknown ERC-4626>
# 0xdf462a9d35e3785b0fb15549a047512b4fc71606  <unknown ERC-4626>
# 0xd919d318c957cd4684998a54dc2c8ab9db9e76bf  <unknown ERC-4626>
# 0xf486608dbc7dd0eb80e4b9fa0fdb03e40f414030  <unknown ERC-4626>
# 0x815c23eca83261b6ec689b60cc4a58b54bc24d8d  <unknown ERC-4626>
# 0x30647a72dc82d7fbb1123ea74716ab8a317eac19  <unknown ERC-4626>
# 0x17d8cbb6bce8cee970a4027d1198f6700a7a6c24  <unknown ERC-4626>
# 0x4937a209d4cdbd3ecd48857277cfd4da4d82914c  <unknown ERC-4626>
# 0x71e639aa132445d1aa2b2efc28f11964a4489277  <unknown ERC-4626>
# 0x8659fc767cad6005de79af65dafe4249c57927af  <unknown ERC-4626>
# 0x12d92fe0aa1c59c4f7a704d16561cfbaf17ec257  <unknown ERC-4626>
# 0xf9f875bd4b1bc19693fe3fe3c719f9deb11a2637  <unknown ERC-4626>
# 0x44dd83e0598e7a3709cf0b2e59d3319418068a65  <unknown ERC-4626>
# 0x86e8062c9f9e5f852bb0d8fc3f33fc110e9b2e47  <unknown ERC-4626>
# 0xdcee1c640cc270121faf145f231fd8ff1d8d5cd4  <unknown ERC-4626>
# 0x08b8a86b9498ac249bf4b86e14c5d4187085a239  <unknown ERC-4626>
# 0xae327c28d13a497357ad2189b75c83e6ba8cadc6  <unknown ERC-4626>
# 0xcea3aa5b2a50e39c7c7755ebff1e9e1e1516d3f5  <unknown ERC-4626>
# 0x4bf99dab15ca5da9ff6a0489509a8f196f9dff9f  <unknown ERC-4626>
# 0x79dfc65f77c67d95652294f301bee5dea3d951fb  <unknown ERC-4626>
# 0xf9a98a9452485ed55cd3ce5260c2b71c9807b11a  <unknown ERC-4626>
# 0xbab1e97e9db257fb2ce11fb7044eacc838db8f11  <unknown ERC-4626>
# 0xbab1e772d70300422312dff12daddcb60864bd41  <unknown ERC-4626>
# 0xdffc232ed74a25031a3e16c81013da22ac75806f  <unknown ERC-4626>
# 0x7bad5df5e11151dc5ee1a648800057c5c934c0d5  <unknown ERC-4626>
# 0xd15135141f1217b8863cb1431ad71309ef22ceda  <unknown ERC-4626>
# 0xb4047ab92ed82c3f29c14010a955da6708a41244  <unknown ERC-4626>
# 0x3808708e761b988d23ae011ed0e12674fb66bd62  <unknown ERC-4626>
# 0x3aea50829e33e976acb05454d356b27d94da9c83  <unknown ERC-4626>
# 0xdb836a975af2f41f82b863f6c22e127fa6fb968a  <unknown ERC-4626>
# 0x1ec71ddf391af2024b06f1c6dbb9a9896ced3015  <unknown ERC-4626>
# 0x10ca519614b0f3463890387c24819001affc5152  <unknown ERC-4626>
# 0x6d800bc192666936d612156f594357dafa8fc290  <unknown ERC-4626>
# 0x00000008786611c72a00909bd8d398b1be195be3  <unknown ERC-4626>
# 0xb9b2ecaa664fdcc6f7104e0cff5f3a690f0b3a4c  <unknown ERC-4626>
# 0x63bbb71b68c76b78243d0a4aa463d34536788a15           <unknown>
# 0xdaf03d70fe637b91ba6e521a32e1fb39256d3ec9  <unknown ERC-4626>
# 0x211bf3fe6f5fc8323e7f684459ceea08507ced94  <unknown ERC-4626>
# 0x48db0de4fed4b978c1aea882bc8d9bf94b15a3b7  <unknown ERC-4626>
# 0x6ebdc53b2c07378662940a7593ad39fb67778457  <unknown ERC-4626>
# 0x794f6b13fbd7eb7ef10d1ed205c9a416910207ff           <unknown>
# 0x32467a5fc2d72d21e8dce990906547a2b012f382           <unknown>
# 0xf4ee75d0d09f14248e942cb94ec909df7c600a85  <unknown ERC-4626>
# 0x8784d80f3308ee0a0f0d40c5623b1454533b84e0  <unknown ERC-4626>
# 0x5ce40e68c1a011c1782499bf5ff01c910c792ba6  <unknown ERC-4626>
# 0x60897720aa966452e8706e74296b018990aec527           <unknown>
# 0x84e1a90a8c1a677db704eb75b2ae79efa325f271           <unknown>
# 0x3c66b18f67ca6c1a71f829e2f6a0c987f97462d0           <unknown>
# 0xf40f9763c56b5b7b264d795fc77a859cdc43d79b  <unknown ERC-4626>
# 0x7ff48b2cbbb4b4d414668bfdbe405cc29e2d1fb3  <unknown ERC-4626>
# 0x20706baa0f89e2dccf48ea549ea5a13b9b30462f           <unknown>
# 0x4169df1b7820702f566cc10938da51f6f597d264           <unknown>
# 0x6bad6a9bcfda3fd60da6834ace5f93b8cfed9598           <unknown>
# 0x93283e9dce1394994a1fd4cdf02ff45ff5cdaac1  <unknown ERC-4626>
# 0x21c8898f1b30fef7af0c0146d2ba7ca34e3244be  <unknown ERC-4626>
# 0xa384c9cca28cc7a58093e4e9a0acacf8c20072fd  <unknown ERC-4626>
# 0x4e7300f74f59afaeccdc0d434758df9be238f0bf  <unknown ERC-4626>
# 0x347c77098a6ffcf1c7af2de9e96a1be854d70602  <unknown ERC-4626>
# 0xa953f0c594365b821a847e7b9f4722e338526699  <unknown ERC-4626>
# 0xac3e018457b222d93114458476f3e3416abbe38f  <unknown ERC-4626>
# 0x33c42ec3a3f46b2afa5f567d713b9d6539f1991a  <unknown ERC-4626>
# 0xc4d57603d47fb842ec11a5332748f9f96d44cbeb           <unknown>
# 0xdbe88dbac39263c47629ebba02b3ef4cf0752a72           <unknown>
# 0xbfc413ea6cb68c05deda0d9aa7daf8e51a7dddff  <unknown ERC-4626>
# 0xede95dbb60d2dca7cf90c42d6f416a2c7dfb4d5e  <unknown ERC-4626>
# 0x6b7f87279982d919bbf85182ddeab179b366d8f2  <unknown ERC-4626>
# 0x7983beb51580fa1e17f52d4e1686c11cbb473bbd  <unknown ERC-4626>
# 0xb4b1500d09c4c07ab65474f7b980f426a5752a0e  <unknown ERC-4626>
# 0x6e2dac3b9e9adc0cbbae2d0b9fd81952a8d33872  <unknown ERC-4626>
# 0xb9b47e72819934d7a5d60bf08cd2c78072383ebb  <unknown ERC-4626>
# 0x98c5910823c2e67d54e4e0c03de44043dbfa7ca8  <unknown ERC-4626>
# 0x87ed92648fae3b3930577c92c8a247b127ed8949  <unknown ERC-4626>
# 0x9614a4c61e45575b56c7e0251f63dcde797d93c5  <unknown ERC-4626>
# 0x455fb969dc06c4aa77e7db3f0686cc05164436d2  <unknown ERC-4626>
# 0x50e627a1df8d665524942ad7ec6392b6ba60293a           <unknown>
# 0x4607da637e5d182419de0118b4c49562bdf09dac  <unknown ERC-4626>
# 0x52ecdbcdca159e020597f6eb7fb90a3e715ea3c1  <unknown ERC-4626>
# 0x87d7fff9c1d2dba7dee527efe7e89257d4fb9209  <unknown ERC-4626>
# 0x3843c41da1d7909c86fad51c47b9a97cf62a29e1  <unknown ERC-4626>
# 0xd6b11df2a86a9ffd3437e6af2ed7889092f66a67  <unknown ERC-4626>
# 0x55dff0b17dcde1a36b1b2987e597a7700fb2241e  <unknown ERC-4626>
# 0x46a24d4b38f4e760005d74bf03b99b1ff096558c  <unknown ERC-4626>
# 0x87f74d68e5c561eb1f9b7e6d3f99483a752d7d6b  <unknown ERC-4626>
# 0x53273ea2feb6c60163b0815da27a184d6055bfde  <unknown ERC-4626>
# 0x39fc9b8df2a36dc70c79ddafafabb4d2e1598f09  <unknown ERC-4626>
# 0x45a6c7d5af31948b79e0eafe7c299e7e20b9ece1  <unknown ERC-4626>
# 0xde3ae5abf47f0a7be34b85a61ecd121807ede4cc  <unknown ERC-4626>
#
#                                                          Denomination  \
# Address
# 0x20ccfcf19c622b4aeb5e476144382b9cff3c63f8
# 0x1e2a7796af48ca59ab1e1aecd30a532cace98eee
# 0xe63c3770823da6f9d9e2fd46bb2e0d0b78f87815
# 0xababb61a9f837aad53ed4320221737fc6e9dc84b
# 0x21db1a295875bdeaf6ce8ed1b1efc04f3c291b89                       TOKE
# 0x4f93df7bc0421c9401fd3099cce4afe7678b0c63                      TRIBE
# 0xac4c093c777581dc9c4dc935394ff11e6c58cd45                        FEI
# 0x5dcaaf1f0b32244131fed00de9c4598ae526dab2                       tTCR
# 0x48f8d7943899d9b4f34ccb5ba1b92695433226e8                cvxFXSFXS-f
# 0x497315203656958b8d82c905ed364ff7d67f0b44               rETHwstETH-f
# 0xa066620554af0d50703e5ee3c58c022c6ae5339d                cvxFXSFXS-f
# 0xb78ebb2248bb72380e690246f9631cf58c07b444                   cvxcrv-f
# 0xd2af830e8cbdfed6cc11bab697bb25496ed6fa62                       OUSD
# 0x4db37c056de510db0ba461ecb02fd0b2925f1473                      TRIBE
# 0xdf462a9d35e3785b0fb15549a047512b4fc71606                        BAL
# 0xd919d318c957cd4684998a54dc2c8ab9db9e76bf                       gOHM
# 0xf486608dbc7dd0eb80e4b9fa0fdb03e40f414030                        FEI
# 0x815c23eca83261b6ec689b60cc4a58b54bc24d8d                       THOR
# 0x30647a72dc82d7fbb1123ea74716ab8a317eac19                       mUSD
# 0x17d8cbb6bce8cee970a4027d1198f6700a7a6c24                       mBTC
# 0x4937a209d4cdbd3ecd48857277cfd4da4d82914c                        MPL
# 0x71e639aa132445d1aa2b2efc28f11964a4489277                       USDC
# 0x8659fc767cad6005de79af65dafe4249c57927af                      pxCVX
# 0x12d92fe0aa1c59c4f7a704d16561cfbaf17ec257               ∞-yvWETH-PYT
# 0xf9f875bd4b1bc19693fe3fe3c719f9deb11a2637                        DAI
# 0x44dd83e0598e7a3709cf0b2e59d3319418068a65                       NEWO
# 0x86e8062c9f9e5f852bb0d8fc3f33fc110e9b2e47                        SLP
# 0xdcee1c640cc270121faf145f231fd8ff1d8d5cd4             B-stETH-STABLE
# 0x08b8a86b9498ac249bf4b86e14c5d4187085a239                    staBAL3
# 0xae327c28d13a497357ad2189b75c83e6ba8cadc6              20WETH-80WNCG
# 0xcea3aa5b2a50e39c7c7755ebff1e9e1e1516d3f5            20WBTC-80BADGER
# 0x4bf99dab15ca5da9ff6a0489509a8f196f9dff9f                      stETH
# 0x79dfc65f77c67d95652294f301bee5dea3d951fb              ∞-wlstETH-PYT
# 0xf9a98a9452485ed55cd3ce5260c2b71c9807b11a                      stETH
# 0xbab1e97e9db257fb2ce11fb7044eacc838db8f11                      stETH
# 0xbab1e772d70300422312dff12daddcb60864bd41                      stETH
# 0xdffc232ed74a25031a3e16c81013da22ac75806f               50DFX-50WETH
# 0x7bad5df5e11151dc5ee1a648800057c5c934c0d5                       USDT
# 0xd15135141f1217b8863cb1431ad71309ef22ceda                       USDT
# 0xb4047ab92ed82c3f29c14010a955da6708a41244                   USDC-PAL
# 0x3808708e761b988d23ae011ed0e12674fb66bd62                        XAI
# 0x3aea50829e33e976acb05454d356b27d94da9c83                       WBTC
# 0xdb836a975af2f41f82b863f6c22e127fa6fb968a                       WBTC
# 0x1ec71ddf391af2024b06f1c6dbb9a9896ced3015                       WETH
# 0x10ca519614b0f3463890387c24819001affc5152  40WBTC-40DIGG-20graviAURA
# 0x6d800bc192666936d612156f594357dafa8fc290                50COW-50GNO
# 0x00000008786611c72a00909bd8d398b1be195be3                       USDC
# 0xb9b2ecaa664fdcc6f7104e0cff5f3a690f0b3a4c               20WETH-80FDT
# 0x63bbb71b68c76b78243d0a4aa463d34536788a15
# 0xdaf03d70fe637b91ba6e521a32e1fb39256d3ec9                     cvxFXS
# 0x211bf3fe6f5fc8323e7f684459ceea08507ced94                      SNACK
# 0x48db0de4fed4b978c1aea882bc8d9bf94b15a3b7               ∞-yvUSDC-PYT
# 0x6ebdc53b2c07378662940a7593ad39fb67778457              B-rETH-STABLE
# 0x794f6b13fbd7eb7ef10d1ed205c9a416910207ff
# 0x32467a5fc2d72d21e8dce990906547a2b012f382
# 0xf4ee75d0d09f14248e942cb94ec909df7c600a85                20DAI-80TCR
# 0x8784d80f3308ee0a0f0d40c5623b1454533b84e0             80TEMPLE-20DAI
# 0x5ce40e68c1a011c1782499bf5ff01c910c792ba6                       USDC
# 0x60897720aa966452e8706e74296b018990aec527
# 0x84e1a90a8c1a677db704eb75b2ae79efa325f271
# 0x3c66b18f67ca6c1a71f829e2f6a0c987f97462d0
# 0xf40f9763c56b5b7b264d795fc77a859cdc43d79b                     VIRTUE
# 0x7ff48b2cbbb4b4d414668bfdbe405cc29e2d1fb3                     VIRTUE
# 0x20706baa0f89e2dccf48ea549ea5a13b9b30462f
# 0x4169df1b7820702f566cc10938da51f6f597d264
# 0x6bad6a9bcfda3fd60da6834ace5f93b8cfed9598
# 0x93283e9dce1394994a1fd4cdf02ff45ff5cdaac1                       WETH
# 0x21c8898f1b30fef7af0c0146d2ba7ca34e3244be                       WETH
# 0xa384c9cca28cc7a58093e4e9a0acacf8c20072fd                      SUSHI
# 0x4e7300f74f59afaeccdc0d434758df9be238f0bf                     frxETH
# 0x347c77098a6ffcf1c7af2de9e96a1be854d70602                       USDC
# 0xa953f0c594365b821a847e7b9f4722e338526699                       USDC
# 0xac3e018457b222d93114458476f3e3416abbe38f                     frxETH
# 0x33c42ec3a3f46b2afa5f567d713b9d6539f1991a                       WETH
# 0xc4d57603d47fb842ec11a5332748f9f96d44cbeb
# 0xdbe88dbac39263c47629ebba02b3ef4cf0752a72
# 0xbfc413ea6cb68c05deda0d9aa7daf8e51a7dddff                       USDC
# 0xede95dbb60d2dca7cf90c42d6f416a2c7dfb4d5e                     yvUSDC
# 0x6b7f87279982d919bbf85182ddeab179b366d8f2                       USDC
# 0x7983beb51580fa1e17f52d4e1686c11cbb473bbd                       WBTC
# 0xb4b1500d09c4c07ab65474f7b980f426a5752a0e                    S*SGETH
# 0x6e2dac3b9e9adc0cbbae2d0b9fd81952a8d33872                       USDC
# 0xb9b47e72819934d7a5d60bf08cd2c78072383ebb                       3Crv
# 0x98c5910823c2e67d54e4e0c03de44043dbfa7ca8                       3Crv
# 0x87ed92648fae3b3930577c92c8a247b127ed8949                       3Crv
# 0x9614a4c61e45575b56c7e0251f63dcde797d93c5                       3Crv
# 0x455fb969dc06c4aa77e7db3f0686cc05164436d2                       USDC
# 0x50e627a1df8d665524942ad7ec6392b6ba60293a
# 0x4607da637e5d182419de0118b4c49562bdf09dac                     S*USDC
# 0x52ecdbcdca159e020597f6eb7fb90a3e715ea3c1                     S*USDC
# 0x87d7fff9c1d2dba7dee527efe7e89257d4fb9209                       WETH
# 0x3843c41da1d7909c86fad51c47b9a97cf62a29e1                     wstETH
# 0xd6b11df2a86a9ffd3437e6af2ed7889092f66a67                       USDC
# 0x55dff0b17dcde1a36b1b2987e597a7700fb2241e                       USDT
# 0x46a24d4b38f4e760005d74bf03b99b1ff096558c                       USDT
# 0x87f74d68e5c561eb1f9b7e6d3f99483a752d7d6b                       USDT
# 0x53273ea2feb6c60163b0815da27a184d6055bfde                       USDT
# 0x39fc9b8df2a36dc70c79ddafafabb4d2e1598f09                       USDT
# 0x45a6c7d5af31948b79e0eafe7c299e7e20b9ece1                       USDC
# 0xde3ae5abf47f0a7be34b85a61ecd121807ede4cc                       USDC
#
#                                                 NAV Mgmt fee Perf fee  \
# Address
# 0x20ccfcf19c622b4aeb5e476144382b9cff3c63f8        0        -        -
# 0x1e2a7796af48ca59ab1e1aecd30a532cace98eee        0        -        -
# 0xe63c3770823da6f9d9e2fd46bb2e0d0b78f87815        0        -        -
# 0xababb61a9f837aad53ed4320221737fc6e9dc84b        0        -        -
# 0x21db1a295875bdeaf6ce8ed1b1efc04f3c291b89  113.915        -        -
# 0x4f93df7bc0421c9401fd3099cce4afe7678b0c63    0.000        -        -
# 0xac4c093c777581dc9c4dc935394ff11e6c58cd45    0.000        -        -
# 0x5dcaaf1f0b32244131fed00de9c4598ae526dab2    0.000        -        -
# 0x48f8d7943899d9b4f34ccb5ba1b92695433226e8    0.358        -        -
# 0x497315203656958b8d82c905ed364ff7d67f0b44    0.000        -        -
# 0xa066620554af0d50703e5ee3c58c022c6ae5339d   59.061        -        -
# 0xb78ebb2248bb72380e690246f9631cf58c07b444     0.0K        -        -
# 0xd2af830e8cbdfed6cc11bab697bb25496ed6fa62     0.6K        -        -
# 0x4db37c056de510db0ba461ecb02fd0b2925f1473    0.000        -        -
# 0xdf462a9d35e3785b0fb15549a047512b4fc71606    0.000        -        -
# 0xd919d318c957cd4684998a54dc2c8ab9db9e76bf    0.000        -        -
# 0xf486608dbc7dd0eb80e4b9fa0fdb03e40f414030    0.000        -        -
# 0x815c23eca83261b6ec689b60cc4a58b54bc24d8d    76.8M        -        -
# 0x30647a72dc82d7fbb1123ea74716ab8a317eac19     2.2M        -        -
# 0x17d8cbb6bce8cee970a4027d1198f6700a7a6c24    0.320        -        -
# 0x4937a209d4cdbd3ecd48857277cfd4da4d82914c     0.0K        -        -
# 0x71e639aa132445d1aa2b2efc28f11964a4489277    0.000        -        -
# 0x8659fc767cad6005de79af65dafe4249c57927af     2.0M        -        -
# 0x12d92fe0aa1c59c4f7a704d16561cfbaf17ec257    2.818        -        -
# 0xf9f875bd4b1bc19693fe3fe3c719f9deb11a2637   47.980        -        -
# 0x44dd83e0598e7a3709cf0b2e59d3319418068a65    12.1M        -        -
# 0x86e8062c9f9e5f852bb0d8fc3f33fc110e9b2e47    0.265        -        -
# 0xdcee1c640cc270121faf145f231fd8ff1d8d5cd4   86.976        -        -
# 0x08b8a86b9498ac249bf4b86e14c5d4187085a239   55.844        -        -
# 0xae327c28d13a497357ad2189b75c83e6ba8cadc6  126.840        -        -
# 0xcea3aa5b2a50e39c7c7755ebff1e9e1e1516d3f5    0.000        -        -
# 0x4bf99dab15ca5da9ff6a0489509a8f196f9dff9f    0.789        -        -
# 0x79dfc65f77c67d95652294f301bee5dea3d951fb    1.417        -        -
# 0xf9a98a9452485ed55cd3ce5260c2b71c9807b11a    2.231        -        -
# 0xbab1e97e9db257fb2ce11fb7044eacc838db8f11    0.000        -        -
# 0xbab1e772d70300422312dff12daddcb60864bd41    2.386        -        -
# 0xdffc232ed74a25031a3e16c81013da22ac75806f    0.000        -        -
# 0x7bad5df5e11151dc5ee1a648800057c5c934c0d5     0.0K        -        -
# 0xd15135141f1217b8863cb1431ad71309ef22ceda    0.179        -        -
# 0xb4047ab92ed82c3f29c14010a955da6708a41244     0.0K        -        -
# 0x3808708e761b988d23ae011ed0e12674fb66bd62   136.6M        -        -
# 0x3aea50829e33e976acb05454d356b27d94da9c83    0.000        -        -
# 0xdb836a975af2f41f82b863f6c22e127fa6fb968a    0.000        -        -
# 0x1ec71ddf391af2024b06f1c6dbb9a9896ced3015    0.000        -        -
# 0x10ca519614b0f3463890387c24819001affc5152    0.000        -        -
# 0x6d800bc192666936d612156f594357dafa8fc290    0.000        -        -
# 0x00000008786611c72a00909bd8d398b1be195be3     0.0K        -        -
# 0xb9b2ecaa664fdcc6f7104e0cff5f3a690f0b3a4c     0.0K        -        -
# 0x63bbb71b68c76b78243d0a4aa463d34536788a15        0        -        -
# 0xdaf03d70fe637b91ba6e521a32e1fb39256d3ec9     0.0K        -        -
# 0x211bf3fe6f5fc8323e7f684459ceea08507ced94     0.7K        -        -
# 0x48db0de4fed4b978c1aea882bc8d9bf94b15a3b7     0.0K        -        -
# 0x6ebdc53b2c07378662940a7593ad39fb67778457    9.431        -        -
# 0x794f6b13fbd7eb7ef10d1ed205c9a416910207ff        0        -        -
# 0x32467a5fc2d72d21e8dce990906547a2b012f382        0        -        -
# 0xf4ee75d0d09f14248e942cb94ec909df7c600a85    0.000        -        -
# 0x8784d80f3308ee0a0f0d40c5623b1454533b84e0    0.000        -        -
# 0x5ce40e68c1a011c1782499bf5ff01c910c792ba6    0.000        -        -
# 0x60897720aa966452e8706e74296b018990aec527        0        -        -
# 0x84e1a90a8c1a677db704eb75b2ae79efa325f271        0        -        -
# 0x3c66b18f67ca6c1a71f829e2f6a0c987f97462d0        0        -        -
# 0xf40f9763c56b5b7b264d795fc77a859cdc43d79b    0.000        -        -
# 0x7ff48b2cbbb4b4d414668bfdbe405cc29e2d1fb3    0.000        -        -
# 0x20706baa0f89e2dccf48ea549ea5a13b9b30462f        0        -        -
# 0x4169df1b7820702f566cc10938da51f6f597d264        0        -        -
# 0x6bad6a9bcfda3fd60da6834ace5f93b8cfed9598        0        -        -
# 0x93283e9dce1394994a1fd4cdf02ff45ff5cdaac1    0.000        -        -
# 0x21c8898f1b30fef7af0c0146d2ba7ca34e3244be   22.030        -        -
# 0xa384c9cca28cc7a58093e4e9a0acacf8c20072fd   23.245        -        -
# 0x4e7300f74f59afaeccdc0d434758df9be238f0bf    0.168        -        -
# 0x347c77098a6ffcf1c7af2de9e96a1be854d70602    0.000        -        -
# 0xa953f0c594365b821a847e7b9f4722e338526699    5.881        -        -
# 0xac3e018457b222d93114458476f3e3416abbe38f     0.1K        -        -
# 0x33c42ec3a3f46b2afa5f567d713b9d6539f1991a    0.000        -        -
# 0xc4d57603d47fb842ec11a5332748f9f96d44cbeb        0        -        -
# 0xdbe88dbac39263c47629ebba02b3ef4cf0752a72        0        -        -
# 0xbfc413ea6cb68c05deda0d9aa7daf8e51a7dddff   21.829        -        -
# 0xede95dbb60d2dca7cf90c42d6f416a2c7dfb4d5e    0.000        -        -
# 0x6b7f87279982d919bbf85182ddeab179b366d8f2     0.0K        -        -
# 0x7983beb51580fa1e17f52d4e1686c11cbb473bbd    0.000        -        -
# 0xb4b1500d09c4c07ab65474f7b980f426a5752a0e    0.000        -        -
# 0x6e2dac3b9e9adc0cbbae2d0b9fd81952a8d33872     0.0K        -        -
# 0xb9b47e72819934d7a5d60bf08cd2c78072383ebb    0.000        -        -
# 0x98c5910823c2e67d54e4e0c03de44043dbfa7ca8    0.000        -        -
# 0x87ed92648fae3b3930577c92c8a247b127ed8949    0.000        -        -
# 0x9614a4c61e45575b56c7e0251f63dcde797d93c5    0.000        -        -
# 0x455fb969dc06c4aa77e7db3f0686cc05164436d2  544.306        -        -
# 0x50e627a1df8d665524942ad7ec6392b6ba60293a        0        -        -
# 0x4607da637e5d182419de0118b4c49562bdf09dac    9.989        -        -
# 0x52ecdbcdca159e020597f6eb7fb90a3e715ea3c1    2.996        -        -
# 0x87d7fff9c1d2dba7dee527efe7e89257d4fb9209    0.000        -        -
# 0x3843c41da1d7909c86fad51c47b9a97cf62a29e1    0.000        -        -
# 0xd6b11df2a86a9ffd3437e6af2ed7889092f66a67    0.330        -        -
# 0x55dff0b17dcde1a36b1b2987e597a7700fb2241e   16.186        -        -
# 0x46a24d4b38f4e760005d74bf03b99b1ff096558c   12.721        -        -
# 0x87f74d68e5c561eb1f9b7e6d3f99483a752d7d6b   16.467        -        -
# 0x53273ea2feb6c60163b0815da27a184d6055bfde    8.646        -        -
# 0x39fc9b8df2a36dc70c79ddafafabb4d2e1598f09   54.020        -        -
# 0x45a6c7d5af31948b79e0eafe7c299e7e20b9ece1    0.597        -        -
# 0xde3ae5abf47f0a7be34b85a61ecd121807ede4cc    0.381        -        -
#
#                                              Shares   First seen
# Address
# 0x20ccfcf19c622b4aeb5e476144382b9cff3c63f8        0  2019-Jun-11
# 0x1e2a7796af48ca59ab1e1aecd30a532cace98eee        0  2019-Jun-12
# 0xe63c3770823da6f9d9e2fd46bb2e0d0b78f87815        0  2019-Jun-14
# 0xababb61a9f837aad53ed4320221737fc6e9dc84b        0  2019-Jun-14
# 0x21db1a295875bdeaf6ce8ed1b1efc04f3c291b89  171.934  2022-Mar-06
# 0x4f93df7bc0421c9401fd3099cce4afe7678b0c63    0.000  2022-Mar-21
# 0xac4c093c777581dc9c4dc935394ff11e6c58cd45    0.000  2022-Mar-22
# 0x5dcaaf1f0b32244131fed00de9c4598ae526dab2    0.000  2022-Mar-30
# 0x48f8d7943899d9b4f34ccb5ba1b92695433226e8    0.358  2022-Apr-04
# 0x497315203656958b8d82c905ed364ff7d67f0b44    0.000  2022-Apr-06
# 0xa066620554af0d50703e5ee3c58c022c6ae5339d   59.061  2022-Apr-06
# 0xb78ebb2248bb72380e690246f9631cf58c07b444     0.0K  2022-Apr-06
# 0xd2af830e8cbdfed6cc11bab697bb25496ed6fa62     0.4K  2022-Apr-11
# 0x4db37c056de510db0ba461ecb02fd0b2925f1473    0.000  2022-Apr-18
# 0xdf462a9d35e3785b0fb15549a047512b4fc71606    0.000  2022-Apr-19
# 0xd919d318c957cd4684998a54dc2c8ab9db9e76bf    0.000  2022-Apr-19
# 0xf486608dbc7dd0eb80e4b9fa0fdb03e40f414030    0.000  2022-Apr-19
# 0x815c23eca83261b6ec689b60cc4a58b54bc24d8d    25.0M  2022-Apr-25
# 0x30647a72dc82d7fbb1123ea74716ab8a317eac19    17.0M  2022-May-18
# 0x17d8cbb6bce8cee970a4027d1198f6700a7a6c24    3.076  2022-May-20
# 0x4937a209d4cdbd3ecd48857277cfd4da4d82914c     0.0K  2022-May-25
# 0x71e639aa132445d1aa2b2efc28f11964a4489277    0.000  2022-May-31
# 0x8659fc767cad6005de79af65dafe4249c57927af     1.0M  2022-May-31
# 0x12d92fe0aa1c59c4f7a704d16561cfbaf17ec257    2.194  2022-Jun-06
# 0xf9f875bd4b1bc19693fe3fe3c719f9deb11a2637   48.090  2022-Jun-06
# 0x44dd83e0598e7a3709cf0b2e59d3319418068a65    23.2M  2022-Jun-15
# 0x86e8062c9f9e5f852bb0d8fc3f33fc110e9b2e47    0.481  2022-Jun-16
# 0xdcee1c640cc270121faf145f231fd8ff1d8d5cd4   86.976  2022-Jun-23
# 0x08b8a86b9498ac249bf4b86e14c5d4187085a239   55.844  2022-Jun-24
# 0xae327c28d13a497357ad2189b75c83e6ba8cadc6  126.840  2022-Jun-24
# 0xcea3aa5b2a50e39c7c7755ebff1e9e1e1516d3f5    0.000  2022-Jun-25
# 0x4bf99dab15ca5da9ff6a0489509a8f196f9dff9f    0.572  2022-Jun-27
# 0x79dfc65f77c67d95652294f301bee5dea3d951fb    1.324  2022-Jul-02
# 0xf9a98a9452485ed55cd3ce5260c2b71c9807b11a    1.847  2022-Jul-02
# 0xbab1e97e9db257fb2ce11fb7044eacc838db8f11    0.000  2022-Jul-04
# 0xbab1e772d70300422312dff12daddcb60864bd41    2.115  2022-Jul-05
# 0xdffc232ed74a25031a3e16c81013da22ac75806f    0.000  2022-Jul-05
# 0x7bad5df5e11151dc5ee1a648800057c5c934c0d5     0.0K  2022-Jul-06
# 0xd15135141f1217b8863cb1431ad71309ef22ceda    0.000  2022-Jul-07
# 0xb4047ab92ed82c3f29c14010a955da6708a41244     0.0K  2022-Jul-09
# 0x3808708e761b988d23ae011ed0e12674fb66bd62    89.5M  2022-Jul-09
# 0x3aea50829e33e976acb05454d356b27d94da9c83    0.000  2022-Jul-11
# 0xdb836a975af2f41f82b863f6c22e127fa6fb968a    0.000  2022-Jul-11
# 0x1ec71ddf391af2024b06f1c6dbb9a9896ced3015    0.000  2022-Jul-11
# 0x10ca519614b0f3463890387c24819001affc5152    0.000  2022-Jul-20
# 0x6d800bc192666936d612156f594357dafa8fc290    0.000  2022-Jul-31
# 0x00000008786611c72a00909bd8d398b1be195be3     0.0K  2022-Aug-01
# 0xb9b2ecaa664fdcc6f7104e0cff5f3a690f0b3a4c     0.0K  2022-Aug-03
# 0x63bbb71b68c76b78243d0a4aa463d34536788a15        0  2022-Aug-18
# 0xdaf03d70fe637b91ba6e521a32e1fb39256d3ec9     0.0K  2022-Aug-18
# 0x211bf3fe6f5fc8323e7f684459ceea08507ced94     0.7K  2022-Aug-23
# 0x48db0de4fed4b978c1aea882bc8d9bf94b15a3b7     0.0K  2022-Aug-25
# 0x6ebdc53b2c07378662940a7593ad39fb67778457    9.431  2022-Aug-30
# 0x794f6b13fbd7eb7ef10d1ed205c9a416910207ff        0  2022-Sep-02
# 0x32467a5fc2d72d21e8dce990906547a2b012f382        0  2022-Sep-02
# 0xf4ee75d0d09f14248e942cb94ec909df7c600a85    0.000  2022-Sep-06
# 0x8784d80f3308ee0a0f0d40c5623b1454533b84e0    0.000  2022-Sep-07
# 0x5ce40e68c1a011c1782499bf5ff01c910c792ba6    0.000  2022-Sep-08
# 0x60897720aa966452e8706e74296b018990aec527        0  2022-Sep-12
# 0x84e1a90a8c1a677db704eb75b2ae79efa325f271        0  2022-Sep-13
# 0x3c66b18f67ca6c1a71f829e2f6a0c987f97462d0        0  2022-Sep-14
# 0xf40f9763c56b5b7b264d795fc77a859cdc43d79b    0.000  2022-Sep-17
# 0x7ff48b2cbbb4b4d414668bfdbe405cc29e2d1fb3    0.000  2022-Sep-20
# 0x20706baa0f89e2dccf48ea549ea5a13b9b30462f        0  2022-Sep-20
# 0x4169df1b7820702f566cc10938da51f6f597d264        0  2022-Sep-21
# 0x6bad6a9bcfda3fd60da6834ace5f93b8cfed9598        0  2022-Sep-26
# 0x93283e9dce1394994a1fd4cdf02ff45ff5cdaac1    0.000  2022-Sep-30
# 0x21c8898f1b30fef7af0c0146d2ba7ca34e3244be   21.191  2022-Sep-30
# 0xa384c9cca28cc7a58093e4e9a0acacf8c20072fd   22.408  2022-Oct-03
# 0x4e7300f74f59afaeccdc0d434758df9be238f0bf    0.000  2022-Oct-04
# 0x347c77098a6ffcf1c7af2de9e96a1be854d70602    0.000  2022-Oct-05
# 0xa953f0c594365b821a847e7b9f4722e338526699    5.881  2022-Oct-05
# 0xac3e018457b222d93114458476f3e3416abbe38f     0.1K  2022-Oct-06
# 0x33c42ec3a3f46b2afa5f567d713b9d6539f1991a    0.000  2022-Oct-06
# 0xc4d57603d47fb842ec11a5332748f9f96d44cbeb        0  2022-Oct-07
# 0xdbe88dbac39263c47629ebba02b3ef4cf0752a72        0  2022-Oct-07
# 0xbfc413ea6cb68c05deda0d9aa7daf8e51a7dddff   20.552  2022-Oct-11
# 0xede95dbb60d2dca7cf90c42d6f416a2c7dfb4d5e    0.000  2022-Oct-12
# 0x6b7f87279982d919bbf85182ddeab179b366d8f2     0.0K  2022-Oct-12
# 0x7983beb51580fa1e17f52d4e1686c11cbb473bbd    0.000  2022-Oct-13
# 0xb4b1500d09c4c07ab65474f7b980f426a5752a0e    0.000  2022-Oct-19
# 0x6e2dac3b9e9adc0cbbae2d0b9fd81952a8d33872     0.0K  2022-Oct-19
# 0xb9b47e72819934d7a5d60bf08cd2c78072383ebb    0.000  2022-Oct-20
# 0x98c5910823c2e67d54e4e0c03de44043dbfa7ca8    0.000  2022-Oct-20
# 0x87ed92648fae3b3930577c92c8a247b127ed8949    0.000  2022-Oct-20
# 0x9614a4c61e45575b56c7e0251f63dcde797d93c5    0.000  2022-Oct-20
# 0x455fb969dc06c4aa77e7db3f0686cc05164436d2  482.919  2022-Oct-20
# 0x50e627a1df8d665524942ad7ec6392b6ba60293a        0  2022-Oct-22
# 0x4607da637e5d182419de0118b4c49562bdf09dac    9.989  2022-Oct-28
# 0x52ecdbcdca159e020597f6eb7fb90a3e715ea3c1    2.996  2022-Oct-30
# 0x87d7fff9c1d2dba7dee527efe7e89257d4fb9209    0.000  2022-Oct-31
# 0x3843c41da1d7909c86fad51c47b9a97cf62a29e1    0.000  2022-Oct-31
# 0xd6b11df2a86a9ffd3437e6af2ed7889092f66a67    0.326  2022-Oct-31
# 0x55dff0b17dcde1a36b1b2987e597a7700fb2241e   15.149  2022-Oct-31
# 0x46a24d4b38f4e760005d74bf03b99b1ff096558c   12.133  2022-Oct-31
# 0x87f74d68e5c561eb1f9b7e6d3f99483a752d7d6b   16.186  2022-Oct-31
# 0x53273ea2feb6c60163b0815da27a184d6055bfde    7.798  2022-Oct-31
# 0x39fc9b8df2a36dc70c79ddafafabb4d2e1598f09     0.0K  2022-Oct-31
# 0x45a6c7d5af31948b79e0eafe7c299e7e20b9ece1    0.574  2022-Oct-31
# 0xde3ae5abf47f0a7be34b85a61ecd121807ede4cc    0.332  2022-Oct-31
